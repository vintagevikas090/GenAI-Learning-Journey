# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage,AIMessage,SystemMessage

load_dotenv()
# Out:
# True

# %%
llm=ChatGroq(model="llama-3.3-70b-versatile")

# %%
response=llm.invoke("What is LangChain?")
print(response.content)
# Out:
# LangChain is an open-source framework designed to help developers build applications that utilize large language models (LLMs) more efficiently. It was created to simplify the process of integrating LLMs into various projects, allowing developers to focus on building their applications rather than spending time on the underlying infrastructure.
#
# LangChain provides a set of tools and APIs that enable developers to interact with LLMs in a more structured and scalable way. Some of the key features of LangChain include:
#
# 1. **Modular architecture**: LangChain allows developers to break down their application into smaller, modular components, making it easier to manage and maintain their codebase.
# 2. **LLM abstraction**: LangChain provides a layer of abstraction between the application code and the LLM, allowing developers to switch between different LLMs or models without modifying their code.
# 3. **Memory management**: LangChain includes features for managing memory and caching, which can help improve the performance and efficiency of LLM-based applications.
# 4. **Data processing**: LangChain provides tools for processing and manipulating data, including support for various data formats and serialization methods.
#
# By using LangChain, developers can build a wide range of applications that leverage the power of LLMs, such as:
#
# 1. **Chatbots and conversational interfaces**
# 2. **Text analysis and summarization tools**
# 3. **Language translation and localization services**
# 4. **Content generation and writing assistants**
#
# Overall, LangChain aims to make it easier for developers to build innovative applications that utilize the capabilities of large language models, while also providing a flexible and scalable framework for managing complex AI workflows.

# %% [markdown]
# ##### Batch Processing

# %%
queries=[
    "What is NLP?",
    "What is RAG?",
    "What is LangChain?"
]

# %%
responses=llm.batch(queries)

# %%
for r in responses:
    print(r.content)
    print("-"*50)
# Out:
# **NLP: Natural Language Processing**
#
# NLP is a subfield of artificial intelligence (AI) that deals with the interaction between computers and humans in natural language. It is a multidisciplinary field that combines computer science, linguistics, and cognitive psychology to enable computers to process, understand, and generate human language.
#
# **Key aspects of NLP:**
#
# 1. **Language understanding**: NLP algorithms are designed to extract meaning from human language, including text, speech, and gestures.
# 2. **Language generation**: NLP systems can generate human-like language, such as text, speech, or chatbot responses.
# 3. **Language processing**: NLP involves various tasks, including tokenization, part-of-speech tagging, named entity recognition, sentiment analysis, and machine translation.
#
# **Applications of NLP:**
#
# 1. **Virtual assistants**: NLP powers virtual assistants like Siri, Alexa, and Google Assistant.
# 2. **Language translation**: NLP enables machine translation, allowing people to communicate across languages.
# 3. **Sentiment analysis**: NLP is used to analyze customer feedback, sentiment, and opinion mining.
# 4. **Chatbots**: NLP powers chatbots, which use human-like language to interact with customers.
# 5. **Text summarization**: NLP can summarize long texts, extracting key points and main ideas.
#
# **Techniques used in NLP:**
#
# 1. **Machine learning**: NLP uses machine learning algorithms, such as supervised and unsupervised learning, to train models on large datasets.
# 2. **Deep learning**: NLP utilizes deep learning techniques, including recurrent neural networks (RNNs) and transformers, to process sequential data.
# 3. **Rule-based systems**: NLP uses rule-based systems, such as grammar and syntax rules, to analyze and generate language.
#
# **Challenges in NLP:**
#
# 1. **Ambiguity**: Human language is often ambiguous, making it difficult for NLP systems to understand the intended meaning.
# 2. **Context**: NLP systems must consider context to accurately understand language.
# 3. **Variability**: Human language is highly variable, with different dialects, accents, and language styles.
#
# Overall, NLP is a rapidly evolving field that has many practical applications in areas like customer service, language translation, and text analysis.
# --------------------------------------------------
# RAG can refer to several things, depending on the context:
#
# 1. **RAG (Raise and Give)**: A fundraising initiative, often found in universities and colleges, where students participate in various events and activities to raise money for charity.
# 2. **RAG (Red, Amber, Green)**: A color-coded system used to indicate the status or risk level of a project, task, or situation. Red typically represents high risk or danger, amber (or yellow) indicates caution or warning, and green signifies low risk or safety.
# 3. **RAG (Revenue, Assurance, and Governance)**: A term used in business and finance to describe the three key aspects of organizational management: revenue generation, assurance (compliance and risk management), and governance (leadership and decision-making).
# 4. **RAG (other meanings)**: RAG can also be an abbreviation for various other terms, such as "RAG" (a type of rock music), "RAG" (a programming language), or "RAG" (a company or organization name).
#
# Without more context, it's difficult to determine which definition is most relevant. If you have any additional information or clarification, I'd be happy to try and provide a more specific answer.
# --------------------------------------------------
# LangChain is an open-source framework and set of tools designed to help developers build applications that utilize large language models (LLMs) like those from OpenAI, Meta, or other providers. The primary goal of LangChain is to simplify the process of integrating LLMs into various projects, making it easier for developers to create more complex and powerful natural language processing (NLP) applications.
#
# LangChain provides a range of features, including:
#
# 1. **Modular architecture**: LangChain allows developers to break down their application into smaller, manageable components, making it easier to integrate LLMs and other NLP tools.
# 2. **Agent-based framework**: LangChain introduces the concept of "agents," which are modular components that can interact with LLMs and other services to perform specific tasks.
# 3. **Memory and knowledge management**: LangChain provides tools for managing memory and knowledge, enabling agents to store and retrieve information, and learn from interactions.
# 4. **Integration with LLMs**: LangChain supports integration with various LLM providers, allowing developers to choose the best model for their specific use case.
# 5. **Extensive library and tools**: LangChain offers a range of pre-built tools and libraries to simplify tasks such as text processing, dialogue management, and more.
#
# By leveraging LangChain, developers can focus on building innovative NLP applications, such as:
#
# 1. **Chatbots and virtual assistants**
# 2. **Text analysis and summarization tools**
# 3. **Content generation and writing assistants**
# 4. **Conversational interfaces for various industries**
#
# Overall, LangChain aims to democratize access to LLMs and NLP technologies, enabling developers to build more sophisticated and powerful applications that can understand and interact with human language.
# --------------------------------------------------

# %% [markdown]
# ##### Stream

# %%
for chunk in llm.stream("Explain vector databases"):
    print(chunk.content,end="")
# Out:
# Vector Databases
# ================
#
# A vector database is a type of database that is designed to efficiently store, index, and query large datasets of dense vectors, typically generated by machine learning models or other high-dimensional data sources. These databases are optimized for similarity search, which is a critical operation in many applications, such as image and video search, recommender systems, and natural language processing.
#
# Key Characteristics
# --------------------
#
# 1. **Vector Data**: Vector databases store data as dense vectors, which are high-dimensional arrays of numerical values.
# 2. **Similarity Search**: The primary operation in a vector database is similarity search, which finds the most similar vectors to a given query vector.
# 3. **Indexing**: Vector databases use indexing techniques to efficiently store and query large datasets.
# 4. **Approximate Nearest Neighbors (ANN)**: Vector databases often use ANN algorithms to find the most similar vectors, which is a trade-off between accuracy and query speed.
#
# Advantages
# ------------
#
# 1. **Efficient Similarity Search**: Vector databases are optimized for similarity search, making them much faster than traditional databases for this operation.
# 2. **Scalability**: Vector databases can handle large datasets and scale horizontally to support high-performance querying.
# 3. **Flexibility**: Vector databases can be used with a variety of data types, including images, text, and audio.
#
# Use Cases
# ------------
#
# 1. **Image and Video Search**: Vector databases are used in image and video search applications to find similar images or videos based on their visual features.
# 2. **Recommender Systems**: Vector databases are used in recommender systems to find similar users or items based on their behavioral data.
# 3. **Natural Language Processing**: Vector databases are used in NLP applications to find similar text documents or to perform semantic search.
#
# Popular Vector Databases
# -------------------------
#
# 1. **Faiss**: Faiss is an open-source vector database developed by Facebook AI Research.
# 2. **Annoy**: Annoy is an open-source vector database developed by Spotify.
# 3. **Hnswlib**: Hnswlib is an open-source vector database developed by Yandex.
# 4. **Pinecone**: Pinecone is a cloud-based vector database that provides a managed service for similarity search.
# 5. **Weaviate**: Weaviate is a cloud-based vector database that provides a managed service for similarity search and data management.
#
# Comparison of Vector Databases
# -------------------------------
#
# | Database | Faiss | Annoy | Hnswlib | Pinecone | Weaviate |
# | --- | --- | --- | --- | --- | --- |
# | **Indexing** | Flat, Hierarchical | Tree-based | Graph-based | Flat, Hierarchical | Graph-based |
# | **ANN Algorithm** | IVF, HNSW | Annoy | HNSW | IVF, HNSW | HNSW |
# | **Scalability** | Horizontal | Horizontal | Horizontal | Horizontal | Horizontal |
# | **Data Types** | Float, Int | Float, Int | Float, Int | Float, Int | Float, Int |
# | **Query Speed** | Fast | Fast | Fast | Fast | Fast |
#
# Conclusion
# ----------
#
# Vector databases are a critical component of many modern applications, including image and video search, recommender systems, and natural language processing. These databases are optimized for similarity search and provide efficient and scalable solutions for large datasets. By understanding the characteristics, advantages, and use cases of vector databases, developers can choose the best database for their specific needs.
