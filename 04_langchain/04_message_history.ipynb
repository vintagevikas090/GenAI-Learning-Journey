# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

load_dotenv()
# Out:
# C:\Users\praja\AppData\Local\Temp\ipykernel_22916\3077363002.py:6: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.chat_message_histories import ChatMessageHistory
# True

# %%
llm=ChatGroq(model="llama-3.3-70b-versatile")

# %%
prompt=ChatPromptTemplate.from_messages([
    ("system","You are a helpful assistant."),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human","{input}")
])

# %%
store={}

# %%
chain=prompt|llm

# %%
def get_session_history(session_id:str)->BaseChatMessageHistory:
    if session_id not in store:
        store[session_id]=ChatMessageHistory()
    return store[session_id]

# %%
chatbot=RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history"
)
# Out:
# d:\AI\genai-learning-journey\venv\Lib\site-packages\IPython\core\interactiveshell.py:3748: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
config={"configurable":{"session_id":"user1"}}

# %%
response=chatbot.invoke(
    {"input":"My name is Vikas."},
    config=config
)

print(response.content)
# Out:
# Hello Vikas, it's nice to meet you. Is there something I can help you with or would you like to chat?

# %%
response=chatbot.invoke(
    {"input":"What is my name?"},
    config=config
)

print(response.content)
# Out:
# Your name is Vikas.

# %%
#### WIth new session

# %%
config2={"configurable":{"session_id":"user2"}}

# %%
response=chatbot.invoke(
    {"input":"What is my name?"},
    config=config2
)

print(response.content)
# Out:
# I don't have that information. I'm a large language model, I don't have the ability to know your personal details, including your name, unless you tell me. If you'd like to share your name with me, I'd be happy to chat with you and use it in our conversation.

# %%
store["user1"].messages
# Out:
# [HumanMessage(content='My name is Vikas.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Hello Vikas, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 47, 'total_tokens': 74, 'completion_time': 0.05370026, 'completion_tokens_details': None, 'prompt_time': 0.002208862, 'prompt_tokens_details': None, 'queue_time': 0.161456998, 'total_time': 0.055909122}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ec62b-7569-77d0-afcb-48add7b45e0a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 27, 'total_tokens': 74}),
#  HumanMessage(content='What is my name?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Your name is Vikas.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 88, 'total_tokens': 95, 'completion_time': 0.009913693, 'completion_tokens_details': None, 'prompt_time': 0.00384564, 'prompt_tokens_details': None, 'queue_time': 0.04709469, 'total_time': 0.013759333}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ec62b-7dbb-7622-9f42-c8a6b789d632-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 88, 'output_tokens': 7, 'total_tokens': 95})]
