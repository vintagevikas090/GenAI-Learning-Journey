# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import MessagesPlaceholder

# %%
prompt = PromptTemplate(
    template="Explain {topic} in simple terms.",
    input_variables=["topic"]
)

prompt.invoke(
    {"topic":"Artificial Intelligence"}
)
# Out:
# StringPromptValue(text='Explain Artificial Intelligence in simple terms.')

# %%
prompt = PromptTemplate(
    template="""
    You are an expert {profession}.
    Explain {topic} to a beginner.
    """,
    input_variables=["profession","topic"]
)

prompt.invoke(
    {
        "profession":"Data Scientist",
        "topic":"Machine Learning"
    }
)
# Out:
# StringPromptValue(text='\nYou are an expert Data Scientist.\n\nExplain Machine Learning to a beginner.\n')

# %%
chat_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are an AI Professor."),
        ("human","Explain {topic}.")
    ]
)

chat_prompt.invoke(
    {
        "topic":"Transformers"
    }
)
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are an AI Professor.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Transformers.', additional_kwargs={}, response_metadata={})])

# %%
chat_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant."),
        MessagesPlaceholder(
            variable_name="chat_history"
        ),
        ("human","{question}")
    ]
)

# %%
chat_prompt.invoke(
    {
        "chat_history":[
            ("human","Hi"),
            ("ai","Hello! How can I help?")
        ],
        "question":"What is LangChain?"
    }
)
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='Hello! How can I help?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is LangChain?', additional_kwargs={}, response_metadata={})])

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are an AI professor."),
        ("human","Explain {topic}")
    ]
)

chain = prompt | llm

response = chain.invoke(
    {
        "topic":"Embeddings"
    }
)

print(response.content)
# Out:
# Embeddings. A fundamental concept in natural language processing (NLP) and machine learning. As an AI professor, I'd be delighted to explain embeddings in detail.
#
# **What are Embeddings?**
#
# Embeddings are a way to represent complex data, such as words, images, or users, as dense vectors in a high-dimensional space. These vectors, also known as embeddings, capture the semantic relationships between the data points, allowing machines to understand and process them more effectively.
#
# **Why do we need Embeddings?**
#
# Traditional machine learning approaches often rely on categorical or numerical representations of data, which can be limiting. For example, in text classification, a word like "dog" might be represented as a one-hot encoded vector, where all other words are zero, and only the "dog" index is one. This representation doesn't capture the nuances of language, such as synonyms, antonyms, or word similarities.
#
# Embeddings address this issue by providing a more meaningful representation of data. They map each data point to a vector in a high-dimensional space, where similar data points are closer together, and dissimilar data points are farther apart.
#
# **Types of Embeddings**
#
# There are several types of embeddings, including:
#
# 1. **Word Embeddings**: These represent words as vectors, capturing their semantic meanings. Word2Vec and GloVe are popular word embedding algorithms.
# 2. **Image Embeddings**: These represent images as vectors, capturing their visual features. Convolutional neural networks (CNNs) can be used to generate image embeddings.
# 3. **User Embeddings**: These represent users as vectors, capturing their preferences, behaviors, or demographics.
# 4. **Graph Embeddings**: These represent graph-structured data, such as social networks or molecular structures, as vectors.
#
# **How are Embeddings learned?**
#
# Embeddings are typically learned using neural networks, which are trained on large datasets. The goal is to minimize a loss function that encourages the model to produce embeddings that are informative and useful for downstream tasks.
#
# Some common techniques for learning embeddings include:
#
# 1. **Self-supervised learning**: The model is trained on a pretext task, such as predicting the next word in a sentence, to learn useful representations.
# 2. **Supervised learning**: The model is trained on a specific task, such as text classification, to learn embeddings that are optimized for that task.
# 3. **Unsupervised learning**: The model is trained on an unsupervised objective, such as reconstructing the input data, to learn general-purpose embeddings.
#
# **Properties of Embeddings**
#
# Embeddings have several desirable properties, including:
#
# 1. **Dense representations**: Embeddings are dense vectors, which can be more efficient and effective than sparse representations.
# 2. **Semantic relationships**: Embeddings capture semantic relationships between data points, such as word similarities or image features.
# 3. **Low-dimensional representations**: Embeddings can be used to reduce the dimensionality of high-dimensional data, making it easier to process and analyze.
#
# **Applications of Embeddings**
#
# Embeddings have numerous applications in NLP, computer vision, and other fields, including:
#
# 1. **Text classification**: Embeddings can be used to improve text classification accuracy by capturing nuanced word meanings.
# 2. **Image recognition**: Embeddings can be used to improve image recognition accuracy by capturing visual features.
# 3. **Recommendation systems**: Embeddings can be used to build recommendation systems that capture user preferences and behaviors.
# 4. **Natural language generation**: Embeddings can be used to generate coherent and context-dependent text.
#
# In conclusion, embeddings are a powerful tool for representing complex data in a meaningful and efficient way. By capturing semantic relationships and nuances, embeddings have revolutionized various applications in NLP, computer vision, and beyond. As an AI professor, I hope this explanation has provided a comprehensive introduction to the world of embeddings.
